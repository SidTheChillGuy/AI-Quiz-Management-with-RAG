# %% [markdown]
# # Requirements
# langchain-google-genai \
# langchain \
# langchain-chroma \
# langchainhub \
# dotenv

# %% [markdown]
# # Import Dependencies

# %%
# Basic libraries
import os
from dotenv import load_dotenv

# Document Conversion libraries
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Vector Store
from langchain_chroma import Chroma

# LLM libraries
from langchain_core.output_parsers import StrOutputParser
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings

# extras
from langchain_core.runnables import RunnablePassthrough
from langchain_classic import hub

# %%
# Load the required Variables
load_dotenv()

if not os.getenv("GOOGLE_API_KEY"):
    raise KeyError("Please Create a .env file with GOOGLE_API_KEY set up.")

# %% [markdown]
# # Data Ingestion Pipeline
#
# <h3>Includes:</h3>
#
# - Document processing
# - Data extraction from documents
# - Chunking
# - Storing in VectorDB

# %%
embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

def load_documents(file_paths):
    all_text = []
    for file in file_paths:
        elements = partition(filename=file)
        text_elements = [element.text for element in elements]
        all_text.append("\n\n".join(text_elements))
        
    print(all_text)
    return "\n\n".join(all_text)

def split_text(text: str):
    text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
        chunk_size=1000,
        chunk_overlap=150)    # change as required
    # print(text_splitter)
    return text_splitter.split_text(text)

def get_vectorstore(chunks):
    embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")
    vector_store = Chroma(
        collection_name="simplerag",
        embedding_function=embeddings,
        persist_directory="./vector_stores/chroma_langchain_db",  # Where to save data locally, remove if not necessary
    )
    return vector_store

# Format retrieved documents into a single string
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %% [markdown]
# # Define Chain for RAG

# %%
prompt = hub.pull("rlm/rag-prompt")
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

def rag_chain(vectorstore, question):
    qa_chain = (
        {
            "context": vectorstore.as_retriever() | format_docs,
            "question": RunnablePassthrough(),
        } | prompt | llm | StrOutputParser()
    )
    return qa_chain.invoke(question)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[13], line 2
#       1 prompt = hub.pull("rlm/rag-prompt")
# ----> 2 llm = ChatGoogleGenerativeAI(
#       3     model="gemini-2.5-flash",
#       4     temperature=0,
#       5     max_tokens=None,
#       6     timeout=None,
#       7     max_retries=2,
#       8 )
#      10 def rag_chain(vectorstore, question):
#      11     qa_chain = (
#      12         {
#      13             "context": vectorstore.as_retriever() | format_docs,
#      14             "question": RunnablePassthrough(),
#      15         } | prompt | llm | StrOutputParser()
#      16     )
#
# File ~/miniconda3/envs/llms/lib/python3.12/site-packages/langchain_google_genai/chat_models.py:1951, in ChatGoogleGenerativeAI.__init__(self, **kwargs)
#    1944         suggestion = (
#    1945             f" Did you mean: '{suggestions[0]}'?" if suggestions else ""
#    1946         )
#    1947         logger.warning(
#    1948             f"Unexpected argument '{arg}' "
#    1949             f"provided to ChatGoogleGenerativeAI.{suggestion}"
#    1950         )
# -> 1951 super().__init__(**kwargs)
#
# File ~/miniconda3/envs/llms/lib/python3.12/site-packages/langchain_core/load/serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/llms/lib/python3.12/site-packages/langchain_google_genai/chat_models.py:2028, in ChatGoogleGenerativeAI.validate_environment(self)
#    2025 if self.base_url and "api_endpoint" not in client_options:
#    2026     client_options = {**client_options, "api_endpoint": self.base_url}
# -> 2028 self.client = genaix.build_generative_service(
#    2029     credentials=self.credentials,
#    2030     api_key=google_api_key,
#    2031     client_info=client_info,
#    2032     client_options=client_options,
#    2033     transport=transport,
#    2034 )
#    2035 self.async_client_running = None
#    2036 return self
#
# File ~/miniconda3/envs/llms/lib/python3.12/site-packages/langchain_google_genai/_genai_extension.py:360, in build_generative_service(credentials, api_key, client_options, client_info, transport)
#     346 def build_generative_service(
#     347     credentials: credentials.Credentials | None = None,
#     348     api_key: str | None = None,
#    (...)    351     transport: str | None = None,
#     352 ) -> v1betaGenerativeServiceClient:
#     353     config = _prepare_config(
#     354         credentials=credentials,
#     355         api_key=api_key,
#    (...)    358         client_info=client_info,
#     359     )
# --> 360     return v1betaGenerativeServiceClient(**config)
#
# File ~/miniconda3/envs/llms/lib/python3.12/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:698, in GenerativeServiceClient.__init__(self, credentials, transport, client_options, client_info)
#     689     transport_init: Union[
#     690         Type[GenerativeServiceTransport],
#     691         Callable[..., GenerativeServiceTransport],
#    (...)    695         else cast(Callable[..., GenerativeServiceTransport], transport)
#     696     )
#     697     # initialize with the provided callable or the passed in class
# --> 698     self._transport = transport_init(
#     699         credentials=credentials,
#     700         credentials_file=self._client_options.credentials_file,
#     701         host=self._api_endpoint,
#     702         scopes=self._client_options.scopes,
#     703         client_cert_source_for_mtls=self._client_cert_source,
#     704         quota_project_id=self._client_options.quota_project_id,
#     705         client_info=client_info,
#     706         always_use_jwt_access=True,
#     707         api_audience=self._client_options.api_audience,
#     708     )
#     710 if "async" not in str(self._transport):
#     711     if CLIENT_LOGGING_SUPPORTED and _LOGGER.isEnabledFor(
#     712         std_logging.DEBUG
#     713     ):  # pragma: NO COVER
#
# File ~/miniconda3/envs/llms/lib/python3.12/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/grpc.py:235, in GenerativeServiceGrpcTransport.__init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info, always_use_jwt_access, api_audience)
#     230             self._ssl_channel_credentials = grpc.ssl_channel_credentials(
#     231                 certificate_chain=cert, private_key=key
#     232             )
#     234 # The base transport sets the host, credentials and scopes
# --> 235 super().__init__(
#     236     host=host,
#     237     credentials=credentials,
#     238     credentials_file=credentials_file,
#     239     scopes=scopes,
#     240     quota_project_id=quota_project_id,
#     241     client_info=client_info,
#     242     always_use_jwt_access=always_use_jwt_access,
#     243     api_audience=api_audience,
#     244 )
#     246 if not self._grpc_channel:
#     247     # initialize with the provided callable or the default channel
#     248     channel_init = channel or type(self).create_channel
#
# File ~/miniconda3/envs/llms/lib/python3.12/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/base.py:105, in GenerativeServiceTransport.__init__(self, host, credentials, credentials_file, scopes, quota_project_id, client_info, always_use_jwt_access, api_audience, **kwargs)
#     101     credentials, _ = google.auth.load_credentials_from_file(
#     102         credentials_file, **scopes_kwargs, quota_project_id=quota_project_id
#     103     )
#     104 elif credentials is None and not self._ignore_credentials:
# --> 105     credentials, _ = google.auth.default(
#     106         **scopes_kwargs, quota_project_id=quota_project_id
#     107     )
#     108     # Don't apply audience if the credentials file passed from user.
#     109     if hasattr(credentials, "with_gdch_audience"):
#
# File ~/miniconda3/envs/llms/lib/python3.12/site-packages/google/auth/_default.py:739, in default(scopes, request, quota_project_id, default_scopes)
#     731             _LOGGER.warning(
#     732                 "No project ID could be determined. Consider running "
#     733                 "`gcloud config set project` or setting the %s "
#     734                 "environment variable",
#     735                 environment_vars.PROJECT,
#     736             )
#     737         return credentials, effective_project_id
# --> 739 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
